# %% [markdown]
# # Final Project Katherine Maki - BIOF 309

# %% [markdown]
# ## Project Question: How many bacterial features (at the genus level) are unique and overlapping across three major taxonomy databases?

# %% [markdown]
# ### What is a bacterial genus?
#
# Bacteria is classified taxonomically ranging from Phylum (high level) to species strain

# %% [markdown]
# ![taxonomy](img/Taxonomy_copy2.png)

# %% [markdown]
# In microbiome analysis, 16S rRNA gene amplicon sequencing is a "culture independent" analysis technique used to classify bacteria based on hypervariable regions in the bacterial 16S rRNA gene. Bacteria is classified based on genetic sequences that are amplified from DNA extracted from a sample. For example, to noninvasively analyze the gut microbiome you can collect and extract DNA from fecal samples :)

# %% [markdown]
# ## Four Databases that will be analyzed
# #### Ribosomal Database Project
# #### Greengenes
# #### Silva
# #### Human Oral Microbiome Database

# %% [markdown]
# ## Links to data
# [Human Oral Microbiome Database](http://www.homd.org/?name=Download&taxonly=1)
# [Silva Release 138](https://www.arb-silva.de/no_cache/download/archive/release_138/Exports/)
# [Greengenes 13_8](https://docs.qiime2.org/2020.2/data-resources/)
# [Ribosomal Database Project V16](https://mothur.org/wiki/rdp_reference_files/)

# %% [markdown]
# ## Data Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Since there are four datasets and they are all formatted differently, we will bring them in seperately and format them to extra characters are deleted, empty columns are changed to "NaN" and the genus data is subsetted

# %% [markdown]
# ### Greengenes is imported first

# %%
#Import GreenGenes Dataset without header
gg = pd.read_table('data_input/gg_99_otu_taxonomy.txt', header=None, names=['id', 'taxonomy'])

# %%
#Split Single Taxonomy Column into Several Columns
gg = gg.taxonomy.str.split(";",expand=True)
gg.columns = ['Kingdom','Phylum','Class',
                     'Order','Family','Genus', 'Species']

# %%
#Get rid of the preceding type labels 
gg.Kingdom = gg.Kingdom.apply(lambda x: x.replace('k__',''))
gg.Phylum = gg.Phylum.apply(lambda x: x.replace('p__',''))
gg.Class = gg.Class.apply(lambda x: x.replace('c__',''))
gg.Order = gg.Order.apply(lambda x: x.replace('o__',''))
gg.Family = gg.Family.apply(lambda x: x.replace('f__',''))
gg.Genus = gg.Genus.apply(lambda x: x.replace('g__',''))
gg.Species = gg.Species.apply(lambda x: x.replace('s__',''))

# %%
#Replace blank spaces with NaN
gg = gg.replace(r'^\s*$', np.nan, regex=True)

# %%
#Add column identifying the dataset
gg['Dataset'] = 'Greengenes'

# %%
#View output
gg.head()
# Out:
#     Kingdom           Phylum                   Class             Order  \
# 0  Bacteria    Cyanobacteria   Synechococcophycideae   Synechococcales
# 1  Bacteria   Proteobacteria     Alphaproteobacteria     Rickettsiales
# 2  Bacteria   Actinobacteria          Actinobacteria   Actinomycetales
# 3  Bacteria       Firmicutes                 Bacilli        Bacillales
# 4  Bacteria       Firmicutes                 Bacilli        Bacillales
#
#                Family            Genus          Species     Dataset
# 0    Synechococcaceae    Synechococcus              NaN  Greengenes
# 1   Pelagibacteraceae              NaN              NaN  Greengenes
# 2    Mycobacteriaceae    Mycobacterium              NaN  Greengenes
# 3   Staphylococcaceae   Staphylococcus              NaN  Greengenes
# 4         Bacillaceae    Anoxybacillus   kestanbolensis  Greengenes

# %%
#Pull out Genus and Dataset Variables
gg_genus =  gg[['Genus', 'Dataset']]

# %%
gg_genus.head()
# Out:
#              Genus     Dataset
# 0    Synechococcus  Greengenes
# 1              NaN  Greengenes
# 2    Mycobacterium  Greengenes
# 3   Staphylococcus  Greengenes
# 4    Anoxybacillus  Greengenes

# %% [markdown]
# ### Next Silva is imported

# %%
#Import GreenGenes Dataset without header
silva = pd.read_table('data_input/silva_consensus_taxonomy_7_levels.txt', header=None, names=['id', 'taxonomy'])

# %%
silva = silva.taxonomy.str.split(";",expand=True)
silva.columns = ['Kingdom','Phylum','Class',
                     'Order','Family','Genus', 'Species']

# %%
#Get rid of the preceding type labels 
silva.Kingdom = silva.Kingdom.apply(lambda x: x.replace('D_0__',''))
silva.Phylum = silva.Phylum.apply(lambda x: x.replace('D_1__',''))
silva.Class = silva.Class.apply(lambda x: x.replace('D_2__',''))
silva.Order = silva.Order.apply(lambda x: x.replace('D_3__',''))
silva.Family = silva.Family.apply(lambda x: x.replace('D_4__',''))
silva.Genus = silva.Genus.apply(lambda x: x.replace('D_5__',''))
silva.Species = silva.Species.apply(lambda x: x.replace('D_6__',''))

# %%
silva.head(40)
# Out:
#      Kingdom              Phylum                Class                  Order  \
# 0   Bacteria  Epsilonbacteraeota      Campylobacteria      Campylobacterales
# 1   Bacteria       Cyanobacteria     Oxyphotobacteria             Nostocales
# 2   Bacteria       Bacteroidetes          Bacteroidia          Bacteroidales
# 3   Bacteria      Proteobacteria  Gammaproteobacteria        Alteromonadales
# 4   Bacteria      Proteobacteria  Gammaproteobacteria      Enterobacteriales
# 5   Bacteria          Firmicutes           Clostridia          Clostridiales
# 6   Bacteria          Firmicutes           Clostridia          Clostridiales
# 7   Bacteria          Firmicutes           Clostridia  Thermolithobacterales
# 8   Bacteria      Actinobacteria       Actinobacteria       Streptomycetales
# 9   Bacteria       Bacteroidetes          Bacteroidia          Bacteroidales
# 10  Bacteria         Tenericutes           Mollicutes      Entomoplasmatales
# 11  Bacteria       Bacteroidetes          Bacteroidia       Flavobacteriales
# 12  Bacteria      Proteobacteria  Deltaproteobacteria      Bdellovibrionales
# 13  Bacteria          Firmicutes           Clostridia          Clostridiales
# 14   Archaea       Crenarchaeota        Bathyarchaeia    uncultured archaeon
# 15  Bacteria      Actinobacteria       Actinobacteria      Micromonosporales
# 16  Bacteria        Rokubacteria                 NC10     Methylomirabilales
# 17  Bacteria          Firmicutes           Clostridia          Clostridiales
# 18  Bacteria          Firmicutes              Bacilli        Lactobacillales
# 19  Bacteria      Proteobacteria  Gammaproteobacteria      Enterobacteriales
# 20  Bacteria      Proteobacteria  Alphaproteobacteria        Caulobacterales
# 21  Bacteria      Proteobacteria  Gammaproteobacteria      Thiomicrospirales
# 34           Rikenellaceae                      Alistipes
# 35  Pseudoalteromonadaceae              Pseudoalteromonas
# 36       Rubinisphaeraceae                        SH-PL14
# 37     uncultured archaeon            uncultured archaeon
# 38           Pirellulaceae                   Pir4 lineage
# 39          Porticoccaceae                    SAR92 clade
#
#                                            Species
# 0                            Sulfuricurvum sp. EW1
# 1   Nostoc sp. 'Nephroma expallidum cyanobiont 23'
# 2                             uncultured bacterium
# 3                            Pseudoalteromonas sp.
# 4                              uncultured organism
# 5                             uncultured bacterium
# 6                       uncultured rumen bacterium
# 7                  Thermolithobacter ferrireducens
# 8                        Streptomyces luteogriseus
# 9                             uncultured bacterium
# 10                       Spiroplasma leptinotarsae
# 11                                  Ambiguous_taxa
# 12                     uncultured Bdellovibrio sp.
# 13                 uncultured Firmicutes bacterium
# 14                             uncultured archaeon
# 15                       Micromonospora sp. 162022
# 16                                  Ambiguous_taxa
# 17                            uncultured bacterium
# 18                           Carnobacterium sp. Y6
# 19                           Budvicia diplopodorum
# 20                            uncultured bacterium
# 21                            uncultured bacterium
# 22                            uncultured bacterium
# 23              uncultured Chromatiaceae bacterium
# 24                 uncultured Firmicutes bacterium
# 25                               Lambia antarctica
# 26                            uncultured bacterium
# 27                            uncultured bacterium
# 28                                Dyella sp. ECB15
# 29                                  Ambiguous_taxa
# 30                         uncultured actinomycete
# 31                             uncultured organism
# 32                             uncultured organism
# 33                            uncultured bacterium
# 34                        uncultured Alistipes sp.
# 35             Pseudoalteromonas telluritireducens
# 36                            uncultured bacterium
# 37                             uncultured archaeon
# 38                                      metagenome
# 39                     uncultured marine bacterium

# %%
silva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369953 entries, 0 to 369952
# Data columns (total 7 columns):
# Kingdom    369953 non-null object
# Phylum     369953 non-null object
# Class      369953 non-null object
# Order      369953 non-null object
# Family     369953 non-null object
# Genus      369953 non-null object
# Species    369953 non-null object
# dtypes: object(7)
# memory usage: 19.8+ MB

# %%
gg_genus.describe()
# Out:
#                Genus     Dataset
# count          93463      203452
# unique          2062           1
# top      Bacteroides  Greengenes
# freq            2747      203452

# %% [markdown]
# ## 2) Provide a link to your data
# Your data is required to be free and open to anyone.
# As such, you should have a URL which anyone can use to download your data:

# %%
# Enter link here.

# %% [markdown]
# ## 3) Import your data
# In the space below, import your data.
# If your data span multiple files, read them all in.
# If applicable, merge or append them as needed.

# %% [markdown]
# ## 4) Show me the head of your data.

# %% [markdown]
# ## 5) Show me the shape of your data

# %% [markdown]
# ## 6) Show me the proportion of missing observations for each column of your data

# %% [markdown]
# ## 7) Give me a problem statement.
# Below, write a problem statement. Keep in mind that your task is to tease out relationships in your data and eventually build a predictive model. Your problem statement can be vague, but you should have a goal in mind. Your problem statement should be between one sentence and one paragraph.

# %% [markdown]
# ## 8) What is your _y_-variable?
# For final project, you will need to perform a statistical model. This means you will have to accurately predict some y-variable for some combination of x-variables. From your problem statement in part 7, what is that y-variable?
